# %%
import pandas as pd 
import numpy as np
import json
from collections import Counter

import re
import string
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer

import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_md")
import textacy
from textacy import extract
from textacy import preprocessing

import matplotlib.pyplot as plt
import seaborn as sns
#sns.set_style('whitegrid')
# %matplotlib inline

import warnings
warnings.simplefilter("ignore", DeprecationWarning)

from sklearn.decomposition import LatentDirichletAllocation as LDA
from pyLDAvis import sklearn as sklearn_lda
import pickle 
import pyLDAvis

from bokeh.io import output_file, show, output_notebook
from bokeh.models import ColumnDataSource
from bokeh.palettes import Category20b, cividis, inferno
from bokeh.plotting import figure
from bokeh.transform import factor_cmap, cumsum
from math import pi

# %% [markdown]
# ## ~~~~~~~~ Helpers ~~~~~~~~

# %%
def flatten_list(_2d_list):
    flat_list = []
    # Iterate through the outer list
    for element in _2d_list:
        if type(element) is list:
            # If the element is of type list, iterate through the sublist
            for item in element:
                flat_list.append(item)
        else:
            flat_list.append(element)
    return flat_list

# %%
f = open('steamdb.json')
data = json.load(f)

# %% [raw]
# with open('steamdb_50000-.json', 'w', encoding='utf-8') as f:
#     json.dump(data[50000:53981], f, ensure_ascii=False, indent=4)

# %%
len(data)
# Out:
# 53981

# %%
df = pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['sid', 'store_url', 'store_promo_url', 'store_uscore',
#        'published_store', 'published_meta', 'published_stsp', 'published_hltb',
#        'published_igdb', 'image', 'name', 'description', 'full_price',
#        'current_price', 'discount', 'platforms', 'developers', 'publishers',
#        'languages', 'voiceovers', 'categories', 'genres', 'tags',
#        'achievements', 'gfq_url', 'gfq_difficulty', 'gfq_difficulty_comment',
#        'gfq_rating', 'gfq_rating_comment', 'gfq_length', 'gfq_length_comment',
#        'stsp_owners', 'stsp_mdntime', 'hltb_url', 'hltb_single',
#        'hltb_complete', 'meta_url', 'meta_score', 'meta_uscore', 'grnk_score',
#        'igdb_url', 'igdb_single', 'igdb_complete', 'igdb_score', 'igdb_uscore',
#        'igdb_popularity'],
#       dtype='object')

# %%
#dict(Counter(df['voiceovers'].dropna().to_list()).items())

# %%
df[['meta_score', 'name']].dropna().sort_values(by='meta_score').head(20)
# Out:
#        meta_score                              name
# 2784         19.0  Alone in the Dark: Illumination™
# 1964         20.0                          Citadels
# 1356         23.0    Flatout 3: Chaos & Destruction
# 294          24.0                        Postal III
# 3669         24.0      Overlord: Fellowship of Evil
# 27797        26.0                          Survivor
# 1524         27.0            Fray: Reloaded Edition
# 12400        27.0                      Troll and I™
# 528          29.0                     Rogue Warrior
# 22128        29.0                    Sniper Rust VR
# 17961        29.0                  Wild West Online
# 9989         30.0          Shaq Fu: A Legend Reborn
# 628          30.0                       Tunnel Rats
# 5100         31.0      The Asskickers-Steam Edition
# 2989         32.0                   Majestic Nights
# 2464         32.0                           Zombeer
# 81           33.0                         X Rebirth
# 12615        33.0              X Rebirth VR Edition
# 1926         34.0               Takedown: Red Sabre
# 1212         34.0       Shadow Harvest: Phantom Ops

# %%
df['hltb_url']
# Out:
# 0         https://howlongtobeat.com/game?id=1953
# 1         https://howlongtobeat.com/game?id=9634
# 2         https://howlongtobeat.com/game?id=2282
# 3         https://howlongtobeat.com/game?id=2373
# 4         https://howlongtobeat.com/game?id=4256
#                           ...
# 53976                                       None
# 53977    https://howlongtobeat.com/game?id=48869
# 53978                                       None
# 53979                                       None
# 53980                                       None
# Name: hltb_url, Length: 53981, dtype: object

# %%
len(df)
# Out:
# 53981

# %%
df.describe()
# Out:
#                 sid  store_uscore    full_price  current_price     discount  \
# count  5.398100e+04  33462.000000  46817.000000   46817.000000  6529.000000
# mean   9.590521e+05     70.453709    907.910631     849.008117    45.406494
# std    4.701868e+05     19.691413   1101.039441    1070.449886    22.180186
# min    1.000000e+01      1.000000     50.000000      49.000000     5.000000
# 25%    5.777600e+05     57.000000    299.000000     299.000000    25.000000
# 50%    9.386800e+05     75.000000    599.000000     500.000000    50.000000
# 75%    1.316230e+06     86.000000   1099.000000     999.000000    60.000000
# max    1.979280e+06    100.000000  99900.000000   99900.000000    90.000000
#
#        achievements    gfq_rating    gfq_length   stsp_owners   stsp_mdntime  \
# count  28716.000000  13491.000000  10710.000000  3.546600e+04    9265.000000
# mean      47.542102      3.333742     17.647460  1.247585e+05     440.549703
# std      290.917125      0.856304     19.267047  1.415364e+06    2235.980563
# min        1.000000      0.500000      0.500000  1.000000e+04       1.000000
# 25%       10.000000      3.000000      5.000000  1.000000e+04      73.000000
# 50%       19.000000      3.500000     10.400000  1.000000e+04     207.000000
# 75%       34.000000      3.920000     20.200000  3.500000e+04     347.000000
# max     9821.000000      5.000000     80.000000  1.500000e+08  137570.000000
#
#         hltb_single  hltb_complete   meta_score  meta_uscore   grnk_score  \
# count  14767.000000   12548.000000  3700.000000  6012.000000  5128.000000
# mean       8.745107      22.940309    71.397297    68.659847    68.723089
# std       56.380258     104.066676    11.097859    14.410269    14.224267
# min        1.000000       1.000000    19.000000     5.000000    10.000000
# 25%        1.000000       2.000000    65.000000    62.000000    60.000000
# 50%        4.000000       7.000000    73.000000    72.000000    70.000000
# 75%        9.000000      18.000000    79.000000    78.000000    80.000000
# max     5149.000000    4871.000000    96.000000   100.000000   100.000000
#
#        igdb_single  igdb_complete   igdb_score   igdb_uscore  igdb_popularity
# count   237.000000     191.000000  4513.000000  12605.000000     21084.000000
# mean     17.075949      37.136126    70.254598     64.685918         2.649404
# std      23.369783      64.806614    13.790916     13.441085        14.434892
# min       1.000000       1.000000    10.000000     11.000000         1.000000
# 25%       3.000000       5.000000    63.000000     50.000000         1.000000
# 50%       8.000000      12.000000    72.000000     70.000000         1.000000
# 75%      21.000000      38.500000    80.000000     74.000000         1.450000
# max     133.000000     400.000000   100.000000    100.000000       997.770000

# %% [markdown]
# ## Correlate user score and game difficulty

# %%
df.groupby(['gfq_difficulty'])[['store_uscore']].mean().reset_index().sort_values(by=['store_uscore'])
# Out:
#       gfq_difficulty  store_uscore
# 8        Unforgiving     66.898551
# 7  Tough-Unforgiving     72.269231
# 6              Tough     73.793157
# 2         Just Right     74.008718
# 1    Easy-Just Right     75.061633
# 3   Just Right-Tough     75.236176
# 0               Easy     75.883629
# 4             Simple     77.049724
# 5        Simple-Easy     78.967742

# %%
df['gfq_difficulty'].dropna().unique()
# Out:
# array(['Just Right-Tough', 'Just Right', 'Easy-Just Right', 'Tough',
#        'Tough-Unforgiving', 'Unforgiving', 'Easy', 'Simple',
#        'Simple-Easy'], dtype=object)

# %% [markdown]
# ## Price

# %%
plt.hist(df['full_price'].dropna()*0.01, 100, density=False, facecolor='g', alpha=0.75)
plt.xlim(0, 60)
# Out:
# (0.0, 60.0)

# %% [markdown]
# ## User ratings

# %%
def get_year(x):
    try:
        return x.split('-')[0] 
    except:
        return 'missing'

# %%
df['year'] = df['published_store'].apply(lambda x : get_year(x))

# %%
scores_by_year = df.groupby('year').mean(['store_uscore'])[['store_uscore']]

# %%
scores_by_year = scores_by_year.reset_index()

# %%
df[df['year']=='2021']
# Out:
#            sid                                   store_url store_promo_url  \
# 42735   354780   https://store.steampowered.com/app/354780            None
# 42736   415780   https://store.steampowered.com/app/415780            None
# 42737   550370   https://store.steampowered.com/app/550370            None
# 42738   570950   https://store.steampowered.com/app/570950            None
# 42739   620890   https://store.steampowered.com/app/620890            None
# ...        ...                                         ...             ...
# 52263  1850240  https://store.steampowered.com/app/1850240            None
# 52286  1851380  https://store.steampowered.com/app/1851380            None
# 52300  1851970  https://store.steampowered.com/app/1851970            None
# 52317  1852760  https://store.steampowered.com/app/1852760            None
# 52428  1857150  https://store.steampowered.com/app/1857150            None
#
#        store_uscore published_store published_meta published_stsp  \
# 42735           NaN      2021-01-08           None           None
# 42736           NaN      2021-01-08           None           None
# 42737           NaN      2021-01-09           None           None
# 42738           NaN      2021-01-29           None           None
# 42739           NaN      2021-01-25           None           None
# ...             ...             ...            ...            ...
# 52263           NaN      2021-12-29           None           None
# 52286           NaN      2021-12-28           None           None
# 52300           NaN      2021-12-28           None           None
# 52317           NaN      2021-12-25           None           None
# 52428           NaN      2021-12-28           None           None
#
#       published_hltb published_igdb  \
# 42735           None           None
# 42736           None           None
# 42737           None           None
# 42738     2021-01-29           None
# 42739           None           None
# ...              ...            ...
# 52263     2021-12-29           None
# 52286     2021-12-28           None
# 52300           None           None
# 52317           None           None
# 52428           None           None
#
#                                                    image  ... meta_uscore  \
# 42735  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
# 42736  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
# 42737  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
# 42738  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
# 42739  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
# ...                                                  ...  ...         ...
# 52263  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
# 52286  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
# 52300  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
# 52317  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
# 52428  https://cdn.akamai.steamstatic.com/steam/apps/...  ...         NaN
#
#       grnk_score  igdb_url  igdb_single  igdb_complete igdb_score igdb_uscore  \
# 42735        NaN      None          NaN            NaN        NaN         NaN
# 42736        NaN      None          NaN            NaN        NaN         NaN
# 42737        NaN      None          NaN            NaN        NaN         NaN
# 42738        NaN      None          NaN            NaN        NaN         NaN
# 42739        NaN      None          NaN            NaN        NaN         NaN
# ...          ...       ...          ...            ...        ...         ...
# 52263        NaN      None          NaN            NaN        NaN         NaN
# 52286        NaN      None          NaN            NaN        NaN         NaN
# 52300        NaN      None          NaN            NaN        NaN         NaN
# 52317        NaN      None          NaN            NaN        NaN         NaN
# 52428        NaN      None          NaN            NaN        NaN         NaN
#
#       igdb_popularity                                    description_bow  year
# 42735             NaN  a pulse-pounding platformer in a neon fueled d...  2021
# 42736             NaN  the pigs have gone mad they are roaming around...  2021
# 42737             NaN  the last sin is a dark jrpg that features many...  2021
# 42738             NaN  strongdevilated is a brutal fps-rpg experience...  2021
# 42739             NaN  wizard bros is a fun couch co-op fighting game...  2021
# ...               ...                                                ...   ...
# 52263             NaN  october 16th 1987 black ridge mountains privat...  2021
# 52286             NaN  stronghappys humble burger barn was the protot...  2021
# 52300             NaN  play as a fallen angel fighting a host of enem...  2021
# 52317             NaN  train your brain with this memory game reveali...  2021
# 52428             NaN  strongdomini gamesstrong invites you on the tr...  2021
#
# [7886 rows x 48 columns]

# %%
scores_by_year
# Out:
#        year  store_uscore
# 0      1997     87.000000
# 1      1998     96.000000
# 2      1999     89.500000
# 3      2000     89.000000
# 4      2001     88.750000
# 5      2002     89.000000
# 6      2003     80.333333
# 7      2004     91.166667
# 8      2005     81.857143
# 9      2006     83.126984
# 10     2007     80.875000
# 11     2008     76.186747
# 12     2009     75.529231
# 13     2010     73.742857
# 14     2011     73.467391
# 15     2012     75.292035
# 16     2013     74.432489
# 17     2014     68.682019
# 18     2015     69.303042
# 19     2016     70.651038
# 20     2017     69.511397
# 21     2018     68.363282
# 22     2019     72.171860
# 23     2020     72.608316
# 24     2021           NaN
# 25     2022           NaN
# 26  missing     71.840336

# %%
source = ColumnDataSource(data=dict(counted_data=scores_by_year.year, counts=scores_by_year.store_uscore))
p = figure(x_range=scores_by_year.year, plot_height=300, plot_width=600, toolbar_location=None, title='Scores')
    
p.vbar(x='counted_data',
    top='counts', 
    width=0.8, 
    source=source, 
    line_color='white', 
)
    
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
p.y_range.start = 0
p.xaxis.major_label_orientation = 1.2
p.background_fill_color = 'white'
    
show(p)
# Out:
#   <div class="bk-root" id="3e84c963-a17e-4e09-b5e9-e01bd4e87939" data-root-id="1367"></div>

# %%
df[df['store_uscore']>96]['publishers'].unique().tolist()
# Out:
# ['Valve',
#  'Square Enix',
#  'Epic Games, Inc.',
#  'Hidden Path Entertainment',
#  'TrueThought',
#  'LucasArts,Lucasfilm,Disney',
#  'FireFly Studios',
#  'Devolver Digital',
#  'Electronic Arts',
#  'TaleWorlds Entertainment',
#  'SEGA,Feral Interactive (Mac/Linux)',
#  'Robot Entertainment',
#  'Re-Logic',
#  'Bethesda Softworks',
#  'Suspicious Developments',
#  'Freebird Games',
#  'Skybound Games',
#  'HeR Interactive',
#  'Ubisoft',
#  'Terry Cavanagh',
#  'Wadjet Eye Games',
#  'SCS Software',
#  'Tripwire Interactive',
#  'Swing Swing Submarine',
#  'The Behemoth',
#  'Athlon Games, Inc.',
#  'Yacht Club Games',
#  'Nicalis, Inc.',
#  'XSEED Games,Marvelous USA, Inc.',
#  'MagicalTimeBean',
#  'Ivy Games',
#  'Spicyhorse Games',
#  'Gears for Breakfast',
#  'Double Fine Presents',
#  'THQ Nordic',
#  'Silver Dollar Games',
#  'Matt Roszak',
#  'Matthew Brown',
#  'Artifex Mundi',
#  'Knuckle Cracker',
#  'PixelNAUTS',
#  'Humongous Entertainment,Nightdive Studios',
#  'Dinosaur Polo Club',
#  'Fireproof Games',
#  'Apparition Games',
#  'CD PROJEKT RED',
#  'Ludeon Studios',
#  'Armor Games Studios',
#  'Cartoon Network Games',
#  'InterAction studios',
#  'Little Worlds Interactive',
#  'MangaGamer',
#  'Adam Spragg',
#  'Daniel Ratcliffe',
#  'Candescent & Section',
#  'Degica',
#  'Sekai Project',
#  'Heartbit Interactive',
#  'Disney',
#  'Breakfall',
#  'Freehold Games',
#  'Demigiant',
#  'Jonas Kyratzes',
#  'Choice of Games',
#  'Steel Crate Games',
#  'Green Man Gaming Publishing',
#  'Instant Kingdom',
#  'Hunter Hamster',
#  'Sanctum Games',
#  'Killmonday Games AB',
#  'Emberheart Games',
#  'Interplay Entertainment Corp.',
#  'Team Cherry',
#  'Maciej Targoni',
#  'Nightdive Studios',
#  'Zachtronics',
#  'Level Eight AB',
#  'FIVE-BN GAMES',
#  'Kieffer Bros.',
#  'Wispfire',
#  'Sørb',
#  'Casual Labs',
#  'Adam Tarnowski',
#  'Double Fine Productions',
#  'Rotten Mage',
#  'Huebotics',
#  'Mason Lindroth',
#  'Dotemu',
#  'Second Variety Games',
#  'G.rev Ltd.',
#  'Ludosity',
#  'Krome Studios',
#  'Spike Chunsoft Co., Ltd.',
#  'ConcernedApe',
#  'Rad Codex',
#  'Lached Up Games',
#  'SculptrVR',
#  'BrainGoodGames',
#  'Hosted Games',
#  ' VisualArts',
#  'SnoutUp',
#  'Wube Software LTD.',
#  'Craftven',
#  'Monomi Park',
#  'Nickervision Studios',
#  'Jackbox Games, Inc.',
#  'HyperBerry Games',
#  'Adriaan de Jongh',
#  'Aldin Dynamics',
#  'Jesper The End',
#  'radio,indienova',
#  'Stellar Circle',
#  'Ysbryd Games,AGM PLAYISM',
#  'Grove Comp',
#  'Enlight Software Limited,Retroism',
#  'RUST LTD.',
#  'JAST USA\t',
#  'Adult Swim Games',
#  'Resni',
#  'Pirate Software',
#  'Hanaji Games,Gamera Game',
#  'Steel Wool Studios',
#  'adamgryu',
#  'MUZBOZ Games',
#  'vested interest',
#  'Big Cow Studios',
#  'My Dog Zorro',
#  'Leaghorn',
#  'Colorspace Studio',
#  'Kivano,Kurki.games',
#  'bad chalk',
#  'Super Legit Games',
#  'Harmonious Games',
#  'Fallen Tree Games Ltd',
#  'Fruitbat Factory',
#  'Miikka Åsnabrygg',
#  'Shambles Software',
#  'Vulgat',
#  'Matt Glanville',
#  'Gosatsu Visual Novels',
#  'Casual Brothers',
#  'Matt Makes Games Inc.',
#  'Quiet River',
#  'Worthing & Moncrieff',
#  'Chris Folea',
#  'Studio GU',
#  'Onyx Lute',
#  'Justin Varghese',
#  'D3 PUBLISHER',
#  'Sad Spaghetti Entertainment',
#  'Green Dinosaur Games',
#  'Magenta Factory',
#  'New Blood Interactive',
#  'HelixFox Games',
#  'Ink Dragon Works',
#  'TANTANMEN',
#  'Taylor Stapleton',
#  'Whirlybird Games',
#  'Whippering',
#  'Berzerk Studio',
#  'Frontwing USA',
#  'Bobbates LLC.',
#  'Oh, a Rock! Studios',
#  'George Gilbert',
#  'wins_84',
#  'New Bridge Games',
#  'Ionized Studios',
#  'peakvox',
#  'HIKARI FIELD',
#  'Nostalgia Addict Games',
#  'Annapurna Interactive',
#  'Interplay',
#  'Laura Shigihara',
#  'Loju',
#  'GamePhase',
#  'magicdweedoo',
#  'VinLia Games',
#  'Circus Atos',
#  'Michaela Laws',
#  'Dicesuki',
#  'Radical Phi',
#  'Daniel Benmergui',
#  'Sköll Studio',
#  'IBOLOGY LLC',
#  'Sector-K Games',
#  'Rolling Crown',
#  'Fred Wood',
#  'ThinkFast Studio',
#  'Team Seven',
#  'Open Sorcery Games',
#  '@unepic_fran',
#  'Sean Tann',
#  'Majorariatto',
#  'HandyGames',
#  'Tolga Ay',
#  'Tall Tail Studios',
#  'Rabbiton',
#  'Braincells Productions Inc.',
#  'Cloak and Dagger Games',
#  'Mark Radocy',
#  'Asymmetric',
#  '9 Eyes Game Studio,Stately Snail',
#  'Tomatotrap',
#  'DynF/X Digital',
#  'Team D-13',
#  'GameHouse',
#  'Optical Override',
#  'Subdream Studios',
#  'Bevan McKechnie',
#  '5minlab',
#  'Titmouse',
#  'brutalsoft',
#  'VisualArts',
#  'Centrosphere Games,CIRCLE Ent.',
#  'Rooftop Panda',
#  'InvertMouse',
#  'Henteko Doujin',
#  'Impostor Cat Games',
#  'Future Proof Games',
#  'Ivanovich Games',
#  'Neko Climax Studios',
#  'Paradise Project',
#  'Mega Crit Games',
#  'KEMCO',
#  'Team Ninja Thumbs',
#  'Anatola Howard',
#  'Frostbullet',
#  'House of How',
#  'ANIM•ACE',
#  'Damp Gnat',
#  'Huw Millward',
#  'Tiny RTS',
#  'indienova',
#  'Abstraction Games',
#  'SlimeSmile',
#  'Make Real',
#  'etaxoft',
#  'TeamTrap',
#  'Graham Garven',
#  'Proc Spine',
#  'Defend the Cake, LLC',
#  'Watercress Studios',
#  'Layton Hawkes',
#  'InnerspaceVR',
#  'PLAYISM',
#  'Psydra Games LLC',
#  'Team Salvato',
#  'Iced Lizard Games',
#  'Hernán Smicht',
#  'Phantom Pine Studios',
#  'NVLMaker',
#  'Gamily Studios',
#  'Grip Top Games',
#  'Playmous,Plug In Digital',
#  'Maniac Games',
#  'ebi-hime',
#  'Stairfall Institute',
#  'Retro Reactor',
#  'Self',
#  'Corey Martin',
#  'Next Zen Mechanics Limited',
#  'Remtairy,Kagura Games',
#  'Fold Up Studios',
#  'Echo607',
#  'GoBit Games',
#  'GrizzlyGames',
#  'RDavis',
#  'KirUn',
#  'Mediascape Co., Ltd.',
#  'Feardemic',
#  'Aleksandar Kuzmanovic Games',
#  'adnzzzzZ',
#  'etherane',
#  'Alawar Entertainment',
#  'Firedog Creative Company Limited',
#  'Bright Onion Studios',
#  'Plug In Digital',
#  'Picorinne Soft',
#  'Team Robot Black Hat',
#  'Pikewin',
#  'yours truly',
#  'The Hidden Levels',
#  'Team DYO',
#  'Sierra Lee',
#  'Argent Games',
#  'Ian MacLarty',
#  'aNCHOR Inc.',
#  'オートリ電子',
#  'Pujia8 Studio',
#  'For Kids',
#  'Supra Games',
#  'danthaigames',
#  'Ithaqua Labs',
#  'PsychoFlux Entertainment',
#  'Sen Games',
#  'MoeNovel',
#  'NekoNyan Ltd.',
#  'Lilith Games',
#  'Hummingwarp Interactive',
#  'GooDCrafter',
#  'Google Inc.',
#  'Anatoliy Loginovskikh',
#  'Giorgi Abelashvili',
#  'SakuraGame',
#  'Ian Lilley',
#  'Manic Hyena',
#  'Blackcross & Taylor',
#  'Hamster On Coke Games',
#  'Flat Cat Games',
#  'FHNBHJ',
#  'Oleksandr Savostianov',
#  'Say Again Studio',
#  'Draftline Games',
#  'Fig Publishing Inc.',
#  'GAMELAB',
#  'Deck13',
#  "Q'Prod",
#  'LAME Dimension',
#  'Spooky Squid Games Inc.',
#  'Digital Tribe',
#  'Itharius',
#  'Jesse Makkonen',
#  'OhNoo Studio',
#  'Klei Entertainment',
#  "Mommy's Best Games",
#  'Greg Lobanov',
#  'Formal Sheep, LLC',
#  'Washbear Studio',
#  'Zerouno Games',
#  'Rightstick Studios',
#  'thebrokenhorn',
#  'IMakeGames',
#  'SPECIAL MAGIC GAMES, LLC',
#  'frecle',
#  3909,
#  'Toge Productions',
#  'Visigames',
#  'CATE',
#  'Deep Dive Interactive LLC',
#  'Secret Location Inc.',
#  'GRIP420 Germany UG (haftungsbeschraenkt)',
#  'Pixile',
#  'Why so serious?,PLAYISM',
#  'Ultimate Games S.A.,Falcon Games S.A.',
#  'Adventure Islands',
#  'NIS America, Inc.',
#  'Narrator',
#  'National Film Board of Canada',
#  '忆夏之铃制作组',
#  'Kastrye',
#  'Alex_redmiau,Jokabide.com',
#  'Fancy Fish Games,Whitethorn Digital',
#  '游学者狐狸',
#  'Koruka',
#  'Corrosive Studios LLC',
#  'LoneDev',
#  '東方幕華祭制作组,Starship Studio',
#  'Ludic Studios',
#  'University of Cambridge Engineering Department',
#  'DANGEN Entertainment',
#  '12B3',
#  'Enigmatic Network',
#  '藍茶高校 Blue Tea College',
#  'Kyuppin',
#  'Oasis Games',
#  'Pugware',
#  'PenguiNet',
#  'Cafe Empty',
#  'Syndicate Atomic LLC. ',
#  'ToastieLabs',
#  'Heavenward Games',
#  'StellarXiela',
#  'Llamasoft Ltd.',
#  'Team Navigator',
#  'Rusty Lake',
#  'YSY Softworks',
#  'utStudio',
#  'HeyBox Interactive',
#  'Rob Jinman',
#  'Grey Alien Games',
#  'Longbow Games',
#  'Crisp App Studio',
#  'Afterburn',
#  'Red Mouse Games',
#  'Kekitopu',
#  'SMU Guildhall',
#  'GonzoVR',
#  'Jetdogs Studios',
#  '迷糊的安安',
#  'Akaba Studio',
#  'Contra Concept',
#  'Team Eleven',
#  'Diehardtales Games',
#  'Thinking-Twins GbR',
#  'Erik Sheader-Smith,1 of 1 Inc.',
#  'Squiddershins',
#  'Vertical Robot',
#  'Studio Sott',
#  'SuckerFree Games',
#  'PixelFade Inc',
#  'Sunscale Studios',
#  'SweetChiel',
#  'TALESSHOP Co., Ltd.',
#  'AllianceInFaith',
#  'Curious Studio',
#  'Microsoft Studios',
#  'Milkbag Games',
#  'Landfall',
#  'Hungry Bear Games',
#  'Kongregate',
#  'devotid Media',
#  'Raw Fury',
#  'Rockwell Studios, LLC',
#  'Really Interactive',
#  'ScottGames',
#  'Hempuli Oy',
#  'Metanaut',
#  'Application Systems Heidelberg',
#  'CAPCOM Co., Ltd.',
#  'AmberDrop',
#  'Butterscotch Shenanigans',
#  'Phaser Lock Interactive',
#  'maJAJa',
#  'Hamumu Games, Inc.',
#  'No More Robots',
#  'Pixeljam',
#  'CGE Digital',
#  'Silver Lemur Games',
#  'Joyient',
#  'Inca Games',
#  'Mega Toast Games',
#  'Yongjustyong',
#  'DuckbearLab',
#  'PQube Limited',
#  'WarMachine',
#  'ARTE France',
#  'in Principle Inc',
#  'NEXT Studios,bilibili',
#  'Skeleton Business',
#  'Colestia',
#  'qureate',
#  'UpsilonGames',
#  'Wahler Digital',
#  'Game Soup LLC',
#  'Stumphead Games LLC',
#  '觀象草圖 Astrolabe Draft',
#  'Bawu Team',
#  'Joseph Gribbin',
#  'SmashGames',
#  'Bitca',
#  'Steamberry Studio',
#  'views Co., Ltd',
#  '吃了就睡工作室',
#  'Cinq-Mars Media',
#  'LimboLane',
#  'Sony Music Entertainment (Japan) Inc. / UNTIES',
#  'GrabTheGames',
#  'Gazoid',
#  'Snkl Studio',
#  'Vikintor',
#  'Goloso Games',
#  'Flippancy Studio',
#  '东方幕华祭制作组',
#  'KyleR',
#  'Moraes Game Studio',
#  'shru',
#  'NanningsGames',
#  'Lost in Days Studio',
#  '冷笑黑妖',
#  'Bart Bonte',
#  'ALFAGAME',
#  'Yuying Zzz',
#  'Lucasfilm,LucasArts,Disney',
#  'IR Studio',
#  'OKYO GAMES',
#  'Team Danger Crew',
#  'toropippi',
#  'Morphcat Games UG',
#  'Vidama Software LLC',
#  'FobTi interactive',
#  'Nickireda',
#  'Gemini Creative Games',
#  ' Crew Lab',
#  'Godot Engine',
#  'Planet Tobor',
#  'Vitamin Games',
#  'Skookum Arts',
#  'Kuupu',
#  'Space Plunge',
#  'Funktronic Labs',
#  'Khud0',
#  'Hammer&Ravens',
#  'Kunpo Games',
#  'Wayward Prophet',
#  'U7 committee,indienova',
#  'Loftur Studio',
#  'Falkenbrew',
#  'Plasterbrain',
#  'Fuming',
#  'Worldwalker Games LLC,WhisperGames',
#  'X.D. Network Inc.',
#  'Luminawesome Games Ltd.',
#  'Yak & Co',
#  'Paralune LLC',
#  'Age of Fear',
#  'Ephemeral Entertainment',
#  'Lornyon',
#  'Diego Ras',
#  'Ultimate Games S.A.,Gaming Factory S.A.',
#  'Vertex Pop',
#  'Ysbryd Games',
#  'Headup',
#  'Yogurt game',
#  'NEKO WORKs,FAKKU',
#  'Whitethorn Digital',
#  'Daedalic Entertainment',
#  'Mikołaj Spychał',
#  '四块二茶会',
#  'SmallBü,Pillow Fight',
#  'Wolfs Moon Studios',
#  'Hanako Games',
#  '7A Games,Kurki.games',
#  'MiSou Games',
#  'Wired Productions',
#  'BOV',
#  'Double Dash Studios',
#  'Vertigo Gaming Inc.',
#  'Sokpop Collective',
#  'Wide Right Interactive',
#  'chaikadev',
#  'Manning Media',
#  'AliveGameStudio',
#  'Qd',
#  'Black Smokers Entertainment',
#  'The Shady Gentlemen',
#  'Cronos Interactive',
#  'SPARSE//GameDev',
#  'Nozhin games studio',
#  'MangaGamer,mirai works',
#  'NekoNyan Ltd.,HIKARI FIELD',
#  'Headup,WhisperGames',
#  'worm club,SUPERHOT PRESENTS',
#  'CarloC',
#  'Blazing Bit Games',
#  'DWANGO Co., Ltd.',
#  'pencil',
#  'Super Spin Digital',
#  'Size Five Games',
#  '凝冰剑斩',
#  'HOBIBOX',
#  'Galaxy Shark Studios',
#  'Sophie Houlden',
#  'Popcannibal',
#  'Stryde Games',
#  'Slothwerks,indienova',
#  'Dipster Productions LLC',
#  'BOON',
#  'Caiysware',
#  'Universal Studios Interactive Entertainment LLC,Gbanga (Millform Inc.)',
#  'Akupara Games',
#  '286studio',
#  '馆叔',
#  'Numskull Games',
#  'DevHour Games, LLC',
#  'Wild River Games',
#  'Beltane Games',
#  '神族宝',
#  'DigiPen Institute of Technology',
#  'Lingtan Studio',
#  'Presentable Games',
#  'Demensa',
#  'BatWorks Software',
#  'Intragames Co.,Ltd',
#  'Patsui Games',
#  'Studio Goya',
#  '2ndBoss',
#  'mestiez',
#  'Unexpected',
#  ' Snail-Ninja Studio',
#  'AnukenDev',
#  'Agelvik',
#  'Sounding Stone / 老奉毊',
#  'TOKYOTOON,Fruitbat Factory',
#  'Carbon Studio',
#  'CFK Co., Ltd.',
#  'Chinykian Games',
#  'Couch Game Crafters',
#  'Minimol Games',
#  'HIKARI FIELD,NekoNyan Ltd.',
#  'Supergiant Games',
#  '4G',
#  'Erotes Studio',
#  'DMM GAMES,ShiraVN',
#  'KOEI TECMO GAMES CO., LTD.',
#  'Take Toad',
#  'AZGames',
#  'HaDe Games',
#  'Lonhong Media',
#  '赤瞳大白猫',
#  'Christopher Evans',
#  'PeriScope Game',
#  'Darkling Room',
#  'ghosthunter',
#  'Octavi Navarro',
#  'EveRecord',
#  'L. Stotch',
#  'Phoenix_co',
#  'Svavelstickan',
#  'DZ',
#  'Walter Machado',
#  'Journey Bound Games',
#  'Happy Snake Games',
#  'DIMANCHE CORP.',
#  'Verlumino Studios LLC',
#  'Edym Pixels',
#  'AIHASTO',
#  'ArenaDev',
#  'SimonCreative',
#  'Tender Claws',
#  'Dreamers',
#  'DVloper',
#  'SPokDev',
#  'Sigyaad Team',
#  'Story Fort LLC',
#  'Transhuman Design',
#  'Pracy Studios',
#  'Dire Wolf',
#  'Tommaso Romanò',
#  'mino_dev LLC,Maple Whispering Limited',
#  'Way Down Deep',
#  'Meta Games',
#  'Fleon Games',
#  'DuskDogStudio,HeartBeat Games',
#  'TABINOMICHI',
#  'Beijing Happy Entertainment Technology',
#  'Space Bear Games',
#  'JAST USA',
#  'Lockpickle',
#  'Tempest Digital Ltd.  暴風數位服務有限公司',
#  'Not Fun Games',
#  'Cliax Games',
#  'HOBIBOX,ShiraVN',
#  'James K. Isaac',
#  'Kirillkrm',
#  'Vector Unit',
#  'HUBLOTS,mirai works',
#  'Nocturnal works',
#  'RewindApp',
#  'Draw Me A Pixel',
#  'Pure Do',
#  ' КиКо',
#  'Plectrum Software',
#  ' Cotton Game',
#  'Mars People Games',
#  '011 Games',
#  "Phr00t's Software",
#  'Nobab Moinuddin',
#  ' khukhrovr',
#  'Stuffed Wombat']

# %% [markdown]
# ## Genres

# %%
genres_per_game = df['genres'].tolist()
genres_per_game = [d.split(',') for d in genres_per_game]
genres = flatten_list(genres_per_game)

# %%
dict(Counter(genres).items())
# Out:
# {'Action': 23137,
#  'Free to Play': 4193,
#  'Strategy': 10495,
#  'Adventure': 20738,
#  'Indie': 39084,
#  'RPG': 9412,
#  'Casual': 21996,
#  'Simulation': 10562,
#  'Racing': 2029,
#  'Massively Multiplayer': 1530,
#  'Nudity': 171,
#  'Violent': 662,
#  'Sports': 2593,
#  'Gore': 410,
#  'Early Access': 7084,
#  'Sexual Content': 159,
#  'Movie': 1,
#  'Game Development': 17,
#  'Приключенческие игры': 1,
#  'Инди': 1}

# %% [markdown]
# ## Tags

# %%
tags_per_game = df['tags'].dropna().tolist()
tags_per_game = [d.split(',') for d in tags_per_game]
tags = flatten_list(tags_per_game)

# %%
tags_dict = dict(Counter(tags).items())

# %%
tags_df = pd.DataFrame.from_dict(tags_dict, orient='index')
tags_df.columns = ['count']

# %%
tags_df.sort_values('count', ascending=False).head(100)
# Out:
#                       count
# Indie                 14731
# Action                 9835
# Adventure              8386
# Casual                 7725
# Singleplayer           4917
# ...                     ...
# PvP                     278
# Isometric               275
# Realistic               275
# Dungeon Crawler         274
# Third-Person Shooter    272
#
# [100 rows x 1 columns]

# %% [markdown]
# ## Developers

# %%
developers_per_game = df['developers'].dropna().tolist()
developers_dict = dict(Counter(developers_per_game).items())

# %%
developers_df = pd.DataFrame.from_dict(developers_dict, orient='index')
developers_df.columns = ['count']

# %%
developers_df.sort_values(by='count', ascending=False).head(20)
# Out:
#                             count
# Choice of Games               132
# Laush Dmitriy Sergeevich      113
# Creobit                       103
# KOEI TECMO GAMES CO., LTD.     92
# Sokpop Collective              87
# Hosted Games                   79
# Blender Games                  71
# Ripknot Systems                62
# RewindApp                      61
# Elephant Games                 60
# SEGA                           55
# Eipix Entertainment            54
# Boogygames Studios             53
# Somer Games                    53
# Nikita "Ghost_RUS"             51
# William at Oxford              49
# ERS G Studios                  48
# ImperiumGame                   47
# Telltale Games                 43
# Snkl Studio                    42

# %% [markdown]
# ## Publishers

# %%
publishers_per_game = df['publishers'].dropna().tolist()
publishers_dict = dict(Counter(publishers_per_game).items())

# %%
publishers_df = pd.DataFrame.from_dict(publishers_dict, orient='index')
publishers_df.columns = ['count']

# %%
publishers_df.sort_values(by='count', ascending=False).head(20)
# Out:
#                             count
# Big Fish Games                399
#                               277
# 8floor                        167
# Strategy First                153
# Square Enix                   144
# SEGA                          142
# Sekai Project                 135
# Choice of Games               132
# Laush Studio                  131
# Ubisoft                       127
# THQ Nordic                    123
# HH-Games                      119
# 1C Entertainment              104
# Degica                        100
# Slitherine Ltd.                99
# Alawar Entertainment           98
# Plug In Digital                98
# Devolver Digital               98
# KOEI TECMO GAMES CO., LTD.     91
# Sokpop Collective              88

# %% [markdown]
# ## Description

# %%
df['description']
# Out:
# 0        Play the world's number 1 online action game. ...
# 1        One of the most popular online action games of...
# 2        Enlist in an intense brand of Axis vs. Allied ...
# 3        Enjoy fast-paced multiplayer gaming with Death...
# 4        Return to the Black Mesa Research Facility as ...
#                                ...
# 53976    Kuggs is a fast-paced shooter with some light ...
# 53977    Grandma Studios invites you on the latest chil...
# 53978    Embark on a deadly journey for survival. Your ...
# 53979    Train your brain with this memory game, reveal...
# 53980    Challenging jigsaw puzzles, featuring adult im...
# Name: description, Length: 53981, dtype: object

# %%
def text_to_bow(text):
    '''
    convert text to just lowercase words
    '''
    # optional if dealing with strings which might contain nan 
    if text == np.nan:
        return text 
    else: 
        text = str(text).lower()
        text = re.sub('\n', ' ', text) 
        text = re.sub('<br>', ' ', text) 
        # remove non alphanumeric characters
        regex = re.compile('[^0-9a-zA-Z- ]')
        text = regex.sub('', text)
        text = re.sub(' +', ' ', text).strip()
        return text

# %%
text_to_bow(df['description'][0])
# Out:
# 'play the worlds number 1 online action game engage in an incredibly realistic brand of terrorist warfare in this wildly popular team-based game ally with teammates to complete strategic missions take out enemy sites rescue hostages your role affects your teams success your teams success affects your role'

# %%
df['description_bow'] = df['description'].apply(lambda x : text_to_bow(x))

# %% [markdown]
# ### Bag of words

# %%
class BagOfWords:
    def __init__(self, data, max_df, min_df, stop_words, ngram_range):
        self.data = data
        self.max_df = max_df 
        self.min_df = min_df 
        self.stop_words = stop_words 
        self.ngram_range = ngram_range 
        self.MyCountVectorizer = CountVectorizer(
            max_df=self.max_df, 
            min_df=self.min_df, 
            stop_words=self.stop_words, 
            ngram_range=self.ngram_range)
        # init the empty vars 
        self.X = ""
        self.feature_names = ""
        self.counts = ""
        self.df_counts = ""
        self.dict_counts = ""
        self.wordcloud = ""
        self.p = ""
        
        
    #fit the count vectorizer 
    def fit_transform(self):
        self.X = self.MyCountVectorizer.fit_transform(self.data)
        
    def get_feature_names(self):
        self.feature_names = self.MyCountVectorizer.get_feature_names()
        
    def get_bow_feature_counts(self): 
        self.counts = self.X.toarray().sum(axis=0)
        # create a df with feature names and counts 
        self.df_counts = pd.DataFrame({"feature_names": self.feature_names, "counts": self.counts}).sort_values(by="counts", ascending=False)
    
    
        # get the data into a dict format of {word: freq} type to feed into the wordcloud 
    def prep_for_wordcloud(self):
        _dict_counts = self.df_counts.set_index("feature_names").to_dict(orient="index")
        self.dict_counts = {}
        for keyword, count in _dict_counts.items():
            self.dict_counts[keyword] = count['counts']
    
    # visualise the word cloud
    def viz_wordcloud(self, background_color="black", max_words=200, width=700, height=400):
        self.wordcloud = WordCloud(background_color=background_color, max_words=max_words, width=width, height=height)
        self.wordcloud.generate_from_frequencies(self.dict_counts)
        #self.wordcloud.to_image()
        
    # bar chart of word frequencies 
    def barchart_wordfreq(self, 
                          num_top_features=30,
                          output_here=True, save_filename="plot", 
                          plot_height=350, plot_width=800, title="Title", bgcolor = "#2b2b2b"):
        
        counted_data = self.df_counts.nlargest(num_top_features, "counts")["feature_names"].tolist()
        counts = self.df_counts.nlargest(num_top_features, "counts")["counts"].tolist()
        # either display in the notebook or save file 
        if output_here:
            output_notebook()
        else:
            output_file(save_filename+".html")
        
        source = ColumnDataSource(data=dict(counted_data=counted_data, counts=counts))
        self.p = figure(x_range=counted_data, plot_height=plot_height, plot_width=plot_width, toolbar_location=None, title=title)
    
        self.p.vbar(x='counted_data',
           top='counts', 
           width=0.8, 
           source=source, 
           line_color='white', 
           fill_color=factor_cmap('counted_data', palette=cividis(len(counted_data)), factors=counted_data))
    
        self.p.xgrid.grid_line_color = None
        self.p.ygrid.grid_line_color = None
        self.p.y_range.start = 0
        self.p.xaxis.major_label_orientation = 1.2
        #p.y_range.end = 5000
        self.p.background_fill_color = bgcolor
    
        show(self.p)

# %%
# initialize the count vectorizer 
bow = BagOfWords(data=df['description_bow'], max_df=0.8, min_df=0.005, stop_words="english", ngram_range=(1, 1))
# fit transform and get the fit-transformed matrix of word frequencies
bow.fit_transform() #bow_bow.X
# get the feature names 
bow.get_feature_names() #bow.feature_names
# get the feature counts 
bow.get_bow_feature_counts() #bow.df_counts

# %%
print("Number of features: {}".format(len(bow.feature_names)))
# Out:
# Number of features: 3097

# %%
bow.df_counts.head(10)
# Out:
#      feature_names  counts
# 1147          game  105017
# 1846           new   35979
# 3068         world   35495
# 1571          lili   31601
# 2020          play   30453
# 2764          time   28008
# 762      different   25924
# 2024       players   22549
# 1557        levels   19862
# 2023        player   19406

# %%
# wordcloud 
bow.prep_for_wordcloud()
bow.viz_wordcloud()
bow.wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=700x400 at 0x7FBF72F11EE0>

# %%
bow.barchart_wordfreq(num_top_features=50, plot_width=1000)
#show(bow.p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="def64c0f-a4e0-4dbe-bf6f-58f36155e6e2" data-root-id="1004"></div>

# %% [markdown]
# # NLP

# %% [markdown]
# ## POS Patterns

# %%
patterns = [
    [{"POS" : "VERB"}, {"POS" : "ADV"}],
    #[{"POS" : "VERB"}, {"POS" : "NOUN"}],
    [{"POS" : "ADJ"}, {"POS" : "NOUN"}]
]

# %%
def get_patterns(text):
    doc = nlp(text)
    pattern = textacy.extract.matches.token_matches(doc, patterns=patterns)
    return list(pattern)

# %%
sample = df['description'].dropna().sample(1000).tolist()
patterns_sample = []
for desc in sample: 
    pattern = get_patterns(desc)
    if (len(pattern) > 0):
        patterns_sample.append(pattern)

# %%
patterns_sample_flat = flatten_list(patterns_sample)
patterns_sample_flat = [str(d) for d in patterns_sample_flat]

# %%
patterns_sample_df = pd.DataFrame.from_dict(
    dict(Counter(patterns_sample_flat).items()), orient='index', columns=['count']
).sort_values(by='count', ascending=False).head(30)

# %%
patterns_sample_df
# Out:
#                      count
# first person            30
# other players           28
# single player           25
# visual novel            22
# new game                21
# same time               19
# virtual reality         17
# first time              17
# new features            14
# main character          14
# open world              13
# unique abilities        13
# wide variety            13
# first game              13
# new weapons             12
# real time               11
# unique weapons          11
# high scores             11
# only way                11
# Good luck               11
# next level              11
# new challenges          10
# real life               10
# special abilities       10
# high score              10
# different enemies       10
# old man                 10
# playable characters      9
# new gameplay             9
# new abilities            9

# %% [markdown]
# ## Key terms

# %%
porg = df['description'].dropna().tolist()[1]

# %%
doc = nlp(porg)

# %%
textacy.extract.keyterms.textrank(doc, normalize="lemma", topn=10)
# Out:
# [('popular online action game', 0.10362860280377198),
#  ('online team warfare', 0.09343172882347828),
#  ('game play mode', 0.06162725599651755),
#  ('Team Fortress Classic', 0.05988255177997531),
#  ('character class', 0.052344869965660804),
#  ('unique weapon', 0.048876264259795604),
#  ('unique style', 0.048508558467738966),
#  ('Demolition Man', 0.03942164796752971),
#  ('Medic', 0.020212235228716246),
#  ('ability', 0.017890077756643266)]

# %%
sample_genre_games = df.dropna(subset=['meta_score'])[df['meta_score'] > 70][df['genres'].apply(lambda x : 'Indie' in x)]['description'].dropna().tolist()
sample_genre_games = [simple_text_clean(d) for d in sample_genre_games]
# Out:
# /var/folders/q3/7wmphwj9575b1g06mj1hl7gr0000gn/T/ipykernel_26262/1105941842.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sample_genre_games = df.dropna(subset=['meta_score'])[df['meta_score'] > 70][df['genres'].apply(lambda x : 'Indie' in x)]['description'].dropna().tolist()

# %%
len(sample_genre_games)
# Out:
# 1057

# %%
keywords_all = []
keywords_all_list = []
for game in sample_genre_games:
    keywords = textacy.extract.keyterms.textrank(nlp(game), normalize="lemma", topn=5)
    keywords_words = [list(d)[0] for d in keywords]
    keywords_all.extend(list(keywords))
    keywords_all_list.extend(keywords_words)

# %%
pd.DataFrame.from_dict(dict(Counter(keywords_all_list).items()), orient='index', columns=['count']).sort_values(by='count', ascending=False).head(20)
# Out:
#                   count
# adventure game       13
# puzzle game          11
# game world           10
# new ability           6
# unique character      6
# new game mode         6
# unique story          5
# new challenge         5
# level editor          5
# game mode             5
# unique world          5
# different way         4
# beautiful world       4
# mysterious world      4
# bonus level           4
# you                   4
# new power             4
# new world             4
# player                4
# open world            4

# %%
sample_indie_games = df[df['genres'].apply(lambda x : 'Indie' in x)]['description'].dropna().tolist()
sample_indie_games = [simple_text_clean(d) for d in sample_indie_games]

# %%
keywords_all = []
keywords_all_list = []
for game in sample_indie_games:
    keywords = textacy.extract.keyterms.textrank(nlp(game), normalize="lemma", topn=5)
    keywords_words = [list(d)[0] for d in keywords]
    keywords_all.extend(list(keywords))
    keywords_all_list.extend(keywords_words)

# %%
pd.DataFrame.from_dict(dict(Counter(keywords_all_list).items()), orient='index', columns=['count']).sort_values(by='count', ascending=False).head(70)
# Out:
#                    count
# adventure game        13
# puzzle game           11
# game world            10
# new ability            6
# unique character       6
# ...                  ...
# puzzle adventure       2
# game developer         2
# unique experience      2
# unique spell           2
# new idea               2
#
# [70 rows x 1 columns]

# %%
#pd.DataFrame(keywords_all)

# %% [markdown]
# High scoring vs low scoring games

# %% [markdown]
# ## Preprocessing

# %%
preproc = preprocessing.make_pipeline(
    preprocessing.replace.hashtags,
    preprocessing.replace.user_handles,
    preprocessing.replace.emojis,
    preprocessing.remove.accents,
    preprocessing.remove.html_tags,
    preprocessing.normalize.whitespace
    #preprocessing.remove.punctuation
)

# %%
preproc(porg)
# Out:
# "Return to the Black Mesa Research Facility as one of the military specialists assigned to eliminate Gordon Freeman. Experience an entirely new episode of single player action. Meet fierce alien opponents, and experiment with new weaponry. Named 'Game of the Year' by the Academy of Interactive Arts and Sciences."

# %%
list(extract.basics.ngrams(doc, 3))
# Out:
# [Black Mesa Research,
#  Mesa Research Facility,
#  military specialists assigned,
#  assigned to eliminate,
#  eliminate Gordon Freeman,
#  Experience an entirely,
#  entirely new episode,
#  episode of single,
#  single player action,
#  Meet fierce alien,
#  fierce alien opponents,
#  experiment with new,
#  Academy of Interactive,
#  Arts and Sciences]

# %% [markdown]
# ## Text similarity

# %% [markdown]
# - How similar are the descriptions of games within the same genre?

# %%
def simple_text_clean(text):
    text = re.sub('\n', ' ', text) 
    text = re.sub('\r', ' ', text) 
    text = preproc(text)
    return text

# %%
textacy.similarity.edits.jaro(df['description'].dropna().tolist()[4], df['description'].dropna().tolist()[5])
# Out:
# 0.661875098827387

# %%
sample_action_games = df[df['genres'].apply(lambda x : 'Action' in x)].sample(1000)['description'].dropna().tolist()
sample_action_games = [simple_text_clean(d) for d in sample_action_games]

# %%
sample_action_games_similarities = []
for i in range(len(sample_action_games)):
    for j in range(len(sample_action_games)):
        if (i < j):
            similarity = textacy.similarity.edits.jaro(sample_action_games[i], sample_action_games[j])
            sample_action_games_similarities.append(similarity)
            if (similarity > 0.9):
                print('1:', sample_action_games[i])
                print('\n')
                print('2:', sample_action_games[j])
                print('\n')
                print('\n')
# Out:
# 1: Rain Island is a one small hold & Gun, boss Rush mini-game of Casual difficulty.Features Casual difficulty Hold & Gun and Boss Rush 20 minutes to 35 minutes playtime
#
#
# 2: Mini Island is a one small hold & Gun, boss Rush mini-game of Casual difficulty.Features Casual difficulty Hold & Gun and Boss Rush 20 minutes to 35 minutes playtime

# %%
np.mean(sample_action_games_similarities)
# Out:
# 0.6588673766563138

# %%
textacy.similarity.edits.jaro('The cat is cute', 'The dog is cute')
# Out:
# 0.8666666666666667

# %% [markdown]
# ## Word in context

# %%
txt = df['description'].tolist()[2]

# %%
doc = nlp(txt)

# %%
pattern = list(extract.keyword_in_context(doc, "game", window_width=30, pad_context=True))

# %%
pattern
# Out:
# []

# %% [markdown]
# ## Part of speech

# %%
wanted_pos = ['PROPN', "VERB", "NOUN", "ADV", "ADJ"]

# %%
# for a single string of text, return a list of the words of the desired pos type
# and a list of the corresponding lemmas 
def collect_pos(pos, text, stopword=False):
    pos_text = []
    pos_lemma = []
    doc = nlp(text)
    for token in doc:
        if token.pos_ == pos and token.is_stop == False:
            pos_text.append(token.text)
            pos_lemma.append(token.lemma_)
    return pos_text, pos_lemma

# %%
def collect_noun_chunks(text):
    noun_chunks = []
    doc = nlp(text)
    for chunk in doc.noun_chunks:
        noun_chunks.append(chunk.text)
    return noun_chunks

# %%
noun_chunks = []
for text in df["description_bow"].tolist():
    noun_chunks.extend(collect_noun_chunks(text))
noun_chunks_counts = pd.Series(noun_chunks).value_counts()

# %%
noun_chunks_counts.head(20)
# Out:
# you           210785
# that           46711
# it             45382
# the game       26624
# them           23782
# they           20013
# who            18031
# which          16684
# we             15259
# he             13524
# what           13439
# this           11938
# the world      11607
# i              11344
# she            10052
# this game       8587
# all             7768
# yourself        7276
# the player      6600
# enemies         6366
# dtype: int64

# %%
def collect_pos(text):
    doc = nlp(text)
    nouns, verbs, adverbs, adjectives, other_pos = [], [], [], [], []
    for token in doc: 
        if token.pos_ == "NOUN" or token.pos_ == "PROPN":
            nouns.append(token.lemma_)
        elif token.pos_ == "VERB":
            verbs.append(token.lemma_)
        elif token.pos_ == "ADV":
            adverbs.append(token.lemma_)
        elif token.pos_ == "ADJ":
            adjectives.append(token.lemma_)
        else:
            other_pos.append(token.text)
    return nouns, verbs, adverbs, adjectives, other_pos

# %%
nouns_all, verbs_all, adverbs_all, adjectives_all, other_pos_all =  [], [], [], [], []
for text in df['description_bow'].tolist():
    nouns, verbs, adverbs, adjectives, other_pos = collect_pos(text)
    nouns_all.extend(nouns)
    verbs_all.extend(verbs)
    adverbs_all.extend(adverbs)
    adjectives_all.extend(adjectives)
    other_pos_all.extend(other_pos)

# %%
all_pos = {}
all_pos['nouns'] = len(nouns_all)
all_pos['verbs'] = len(verbs_all)
all_pos['adverbs'] = len(adverbs_all)
all_pos['adjectives'] = len(adjectives_all)

# %%
data_viz = pd.DataFrame.from_dict(all_pos, orient="index").reset_index()
data_viz.columns = ['pos', 'value']

# %%
data_viz
# Out:
#           pos    value
# 0       nouns  3576382
# 1       verbs  1542137
# 2     adverbs   364225
# 3  adjectives  1122006

# %%
#data = pd.DataFrame({"pos": ["nouns", "verbs"], "value" : [len(all_nouns), len(all_verbs)]})
data_viz['angle'] = data_viz['value']/data_viz['value'].sum() * 2*pi
data_viz['color'] = cividis(4)

p = figure(plot_height=350, title="Frequency of each pos type", toolbar_location=None,
           tools="hover", tooltips="@pos: @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='pos', source=data_viz)

p.axis.axis_label=None
p.axis.visible=False
p.grid.grid_line_color = None

show(p)
# Out:
#   <div class="bk-root" id="2e5ef087-62da-4bd9-bafc-60277a45f358" data-root-id="1103"></div>

# %%
nouns_df = pd.DataFrame.from_dict(dict(Counter(nouns_all).items()), orient='index')
nouns_df.columns = ['count']
nouns_df.sort_values(by='count', ascending=False).head(20)
# Out:
#              count
# game        120063
# player       41549
# world        39857
# level        34030
# lili         31262
# time         30555
# enemy        26033
# mode         23483
# character    22197
# story        20841
# way          20376
# puzzle       18728
# weapon       18100
# battle       15684
# system       14435
# skill        14371
# adventure    14073
# friend       14023
# experience   13484
# life         13101

# %%
adj_df = pd.DataFrame.from_dict(dict(Counter(adjectives_all).items()), orient='index')
adj_df.columns = ['count']
adj_df.sort_values(by='count', ascending=False).head(20)
# Out:
#            count
# new        35456
# different  25858
# more       21396
# unique     19143
# own        17450
# other      16946
# good       13258
# many       12744
# strong     10674
# first      10339
# high        9527
# full        9296
# real        8522
# -           7659
# great       7291
# special     7182
# various     7135
# free        6755
# powerful    6632
# easy        6142

# %%
verbs_df = pd.DataFrame.from_dict(dict(Counter(verbs_all).items()), orient='index')
verbs_df.columns = ['count']
verbs_df.sort_values(by='count', ascending=False).head(20)
# Out:
#          count
# have     40574
# play     30567
# make     28344
# use      28323
# find     25002
# get      23588
# take     23445
# go       14363
# create   14198
# be       13570
# need     12558
# explore  12479
# base     12210
# include  12060
# build    11848
# fight    11419
# choose   11001
# feature  10989
# come     10839
# help     10621

# %%
adv_df = pd.DataFrame.from_dict(dict(Counter(adverbs_all).items()), orient='index')
adv_df.columns = ['count']
adv_df.sort_values(by='count', ascending=False).head(20)
# Out:
#           count
# also      14603
# only      12953
# just      11763
# more      11702
# even      11564
# as        10678
# so         9381
# well       9092
# now        9018
# most       7431
# back       7305
# very       6929
# then       6770
# together   5306
# ever       5219
# fast       5072
# never      5013
# long       4465
# all        4209
# always     4184

# %%
displacy.render(nlp(df['description'].dropna().tolist()[7]), style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">With its extensive
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tour of Duty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  campaign, a near-limitless number of skirmish modes, updates and new content for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Counter-Strike's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  award-winning multiplayer game play, plus over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bonus single player missions,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Counter-Strike: Condition Zero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a tremendous offering of single and multiplayer content.</div></span>
